# %% [markdown]
# # print result with string

# %%
num1=20
num2=30
add=num1+num2
print('The addition of',num1,'and',num2,'is=',add)
# Out:
# The addition of 20 and 30 is= 50

# %%
name='Python'
age=20
city='hyd'
print('My name is',name,'and i am',age,'and','years old from',city)
# Out:
# My name is Python and i am 20 and years old from hyd

# %% [markdown]
# # print format method

# %%
num1=20
num2=30
add=num1+num2
print('The addition of{} and {} is={}'.format(num1,num2,add))
# Out:
# The addition of20 and 30 is=50

# %%
name='Python'
age=20
city='hyd'
print('Hello my name is {},and i am {} years old from {}'.format(name,age,city))
# Out:
# Hello my name is Python,and i am 20 years old from hyd

# %%
num1=100
num2=25
num3=333
avg=(num1+num2+num3)/3
avg1=round((num1+num2+num3)/3,2)
print('The average of{},{} and {} is={} or {}'.format(num1,num2,num3,avg,avg1))
# Out:
# The average of100,25 and 333 is=152.66666666666666 or 152.67

# %% [markdown]
# # f string

# %%
num1=20
num2=30
add=num1+num2
print(f'The addition of{num1} and {num2} is={add}')
# Out:
# The addition of20 and 30 is=50

# %%
num1=100
num2=25
num3=333
avg=round((num1+num2+num3)/3,2)
print(f'The average of{num1},{num2} and {num3} is={avg}')
# Out:
# The average of100,25 and 333 is=152.67

# %%
num1=20
num2=30
add=num1+num2
print('The addition of',num1,'and',num2,'is=',add)
print('The addition of{} and {} is={}'.format(num1,num2,add))
print(f'The addition of{num1} and {num2} is={add}')
# Out:
# The addition of 20 and 30 is= 50
# The addition of20 and 30 is=50
# The addition of20 and 30 is=50

# %% [markdown]
# # end statement

# %%
print('hello')
print('good morning')
# Out:
# hello
# good morning

# %%
print('hello',end=' ')
print('good morning')
# Out:
# hello good morning

# %% [markdown]
# # separator

# %%
print('hello','hii','how are you',sep='--->')
# Out:
# hello--->hii--->how are you

# %%
print('hello','hii','how are you',sep=' @  ')
# Out:
# hello @  hii @  how are you

# %%
print('hello','hii','how are you',sep=' & ')
# Out:
# hello & hii & how are you

# %%
print(3,'.')
# Out:
# 3 .

# %%
print(1,2,end=' ')
print(3,'.',sep=' ')
# Out:
# 1 2 3 .
