# %% [markdown]
# # Slice [start:end:step]

# %%
 s='welcome'

# %%
s[1:]
# Out:
# 'elcome'

# %%
s[:1]
# Out:
# 'w'

# %%
s[:]
# Out:
# 'welcome'

# %%
s[3:]
# Out:
# 'come'

# %%
s[:3]
# Out:
# 'wel'

# %%
s[-2:]
# Out:
# 'me'

# %%
s[:-1]
# Out:
# 'welcom'

# %%
s[-4:]
# Out:
# 'come'

# %%
s[:-4]
# Out:
# 'wel'

# %%
s[1:2]
# Out:
# 'e'

# %%
s[:4]
# Out:
# 'welc'

# %%
id(s)
# Out:
# 2755058859296

# %% [markdown]
# # string creation

# %%
str1= "HELLO PYTHON"
print(str1)
# Out:
# HELLO PYTHON

# %%
mystr= 'HELLO WORLD' 
print(mystr) # Define string using single quotes
# Out:
# HELLO WORLD

# %%
mystr= "HELLO WORLD" 
print(mystr) # Define string using double quotes
# Out:
# HELLO WORLD

# %%
mystr='''HELLO 
          WORLD'''
print(mystr) # Define string using triple quotes
# Out:
# HELLO
#           WORLD

# %%
mystr= ('HAPPY'
        'MONDAY'
        'EVERYONE')
print(mystr)
# Out:
# HAPPYMONDAYEVERYONE

# %%
mystr= ('HAPPY '
         'MONDAY '
         'EVERYONE')
print(mystr)
# Out:
# HAPPY MONDAY EVERYONE

# %%
mystr2= 'Woohoo '
mystr2= mystr2*5
mystr2
# Out:
# 'Woohoo Woohoo Woohoo Woohoo Woohoo '

# %%
len(mystr2) # Length of string
# Out:
# 35

# %%
str1
# Out:
# 'HELLO PYTHON'

# %%
str1[0] # first character in string "str1"
# Out:
# 'H'

# %%
str1[len(str1)-1] # Last character in string using len function
# Out:
# 'N'

# %%
str1[-1] # last character in string
# Out:
# 'N'

# %%
str1[6]
# Out:
# 'P'

# %%
str1[5]
# Out:
# ' '

# %% [markdown]
# # string slicing

# %%
str1[0:5] # string slicing - fetch all characters from 0 to location exc
# Out:
# 'HELLO'

# %%
str1[6:12] # string slicing -retrieve all character between 6-12 index location
# Out:
# 'PYTHON'

# %%
str1[-4:]  # Retrieve last four characters of the string
# Out:
# 'THON'

# %%
str1[-6:] # retrieve last six characters of the string
# Out:
# 'PYTHON'

# %%
str1[:4] # Retreive first four characeters of the string
# Out:
# 'HELL'

# %%
str1[:6] # Retreive first six characters of the string
# Out:
# 'HELLO '

# %% [markdown]
# # Update & Delete string

# %%
str1
# Out:
# 'HELLO PYTHON'

# %%
str1[0:5]= 'HOLLAA'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 str1[0:5]= 'HOLLAA'
#
# TypeError: 'str' object does not support item assignment

# %%
del str1 # Delete a string
print(srt1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 del str1 # Delete a string
# ----> 2 print(srt1)
#
# NameError: name 'srt1' is not defined

# %% [markdown]
# # string concatenation

# %%
# string concatenation
s1 = "Hello"
s2 = "Guddu"
s3 = s1 +" "+ s2
print(s3)
# Out:
# Hello Gudu

# %%
print(s3)
