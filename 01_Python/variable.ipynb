# %%
x=1

type(x)
# Out:
# int

# %%
type(a)

d=2.544

type(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x
#       2
#       3 b=aaaaa
#       4
#
# NameError: name 'x' is not defined

# %%
e='adasdasd'

e

y= 2.33
z= 5
a= y+z

a

x=12
a=2.55
b= x-a

b

d=8.32
e=9.5
f=d-e

f

type(f)

e= 8
f=5
g=e*f

g

d=30
e=3
f=d/e

f

j=98
k=7.5
l=j//k

l

d=3
e=4
l=d*e

l

a=5
b=2
c=a**b

c

av=3
bv=4
cv=av**bv

cv

# python_datatype

c1=10+30j
c2=20+40j


c2

c2.real

c2.imag

c3=c1+c2

print(c3)

print(c1)
print(c2)

print(c3)

print(c3)

c4=8+5j
c5=9+3j
c6= c4+c5

c6

print('hello') # 1st statement
print('good moorning') # 2nd statement)


print('hello, how are you?.',end=' regards, suraj')

print('hello, how are you?.uasydgiufho;jjjp asdfaaaaaaaaaaaaaa asedfffffffffffffffff.',end='\nregards,\n suraj')

# %%
e='adasdasd'

e

y= 2.33
z= 5
a= y+z

a

x=12
a=2.55
b= x-a

b

d=8.32
e=9.5
f=d-e

f

type(f)

e= 8
f=5
g=e*f

g

d=30
e=3
f=d/e

f

j=98
k=7.5
l=j//k

l

d=3
e=4
l=d*e

l

a=5
b=2
c=a**b

c

av=3
bv=4
cv=av**bv

cv

# python_datatype

c1=10+30j
c2=20+40j


c2

c2.real

c2.imag

c3=c1+c2

print(c3)

print(c1)
print(c2)

print(c3)

print(c3)

c4=8+5j
c5=9+3j
c6= c4+c5

c6

print('hello') # 1st statement
print('good moorning') # 2nd statement)


print('hello, how are you?.',end=' regards, suraj')

print('hello, how are you?.uasydgiufho;jjjp asdfaaaaaaaaaaaaaa asedfffffffffffffffff.',end='\nregards,\n suraj')
