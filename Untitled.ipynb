# %%
import numpy as np

# %%
np.
# Out:
#   Cell In[5], line 1
#     np.
#        ^
# SyntaxError: invalid syntax

# %%
np._version_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 np._version_
#
# NameError: name 'np' is not defined
